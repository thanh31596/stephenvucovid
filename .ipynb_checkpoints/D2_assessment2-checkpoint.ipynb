# %%
pip install kmodes
# Out:
# Collecting kmodes
#   Downloading kmodes-0.10.2-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\acer\anaconda3\lib\site-packages (from kmodes) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.19.0 in c:\users\acer\anaconda3\lib\site-packages (from kmodes) (0.22.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\acer\anaconda3\lib\site-packages (from kmodes) (0.14.1)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\acer\anaconda3\lib\site-packages (from kmodes) (1.18.1)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import libraries here:
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn import cluster
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

# %% [markdown]
# # Project b: Clustering Mobility Data

# %%
df= pd.read_csv(r'D2.csv')
df['date']=pd.to_datetime(df['date'])
df=df[df.grocery_and_pharmacy.notnull()]
df.drop('date', axis=1, inplace=True)
df=df.fillna(df.mean())
convert_dict = {'retail': int, 'retail': int,'grocery_and_pharmacy': int,'parks': int,'transit_stations': int,'residential': int } 
  
df = df.astype(convert_dict)

# %%
df2=df
df2=df2.drop(['region','country'], axis=1)

# %% [markdown]
# #### Understand data quality

# %%
df2
# Out:
#       retail  grocery_and_pharmacy  parks  transit_stations  workplaces  \
# 0        -63                   -32    -74               -79         -55
# 1        -54                   -23    -66               -75         -47
# 2        -49                   -26    -83               -50         -46
# 3        -76                   -42    -78               -81         -64
# 4        -46                   -22    -43               -56         -30
# ...      ...                   ...    ...               ...         ...
# 1125     -67                   -38    -19               -53         -64
# 1126     -63                   -33    -23               -72         -59
# 1127     -75                   -42    -75               -84         -75
# 1128     -18                   -10     -6               -23         -19
# 1129     -62                   -50    -48               -77         -64
#
#       residential
# 0              34
# 1              28
# 2              29
# 3              41
# 4              21
# ...           ...
# 1125           32
# 1126           29
# 1127           37
# 1128           12
# 1129           42
#
# [942 rows x 6 columns]

# %%
#Identifying outliers
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return len(outliers)
from pandas.api.types import is_numeric_dtype
for col in df.columns:
    if is_numeric_dtype(df[col]):
        a=detect_outlier(df[col])
        print(df[col].name+ " : " +str(a) + ' outliers')
        outliers.clear()
# Out:
# retail : 0 outliers
# grocery_and_pharmacy : 1 outliers
# parks : 9 outliers
# transit_stations : 3 outliers
# workplaces : 3 outliers
# residential : 1 outliers

# %%
#Remove outliers
from scipy import stats
idx = np.all(stats.zscore(df2)<3, axis=1) & np.all(stats.zscore(df2)>-3, axis=1)
dfr_cleaned = df2.loc[idx]
print("Before transformation: %d", df2.shape)
print("After removing outliers: %d", dfr_cleaned.shape)
# Out:
# Before transformation: %d (942, 7)
# After removing outliers: %d (926, 7)

# %% [markdown]
# ### Task 2: Build a clustering model to profile the categories of locations visited by the people

# %%
ax = sns.boxplot(x=dfr_cleaned["retail"], data=df2)

# %%
ax = sns.boxplot(x=dfr_cleaned["grocery_and_pharmacy"], data=dfr_cleaned)

# %%
ax = sns.boxplot(x=dfr_cleaned["parks"], data=df2)

# %%
ax = sns.boxplot(x=dfr_cleaned["transit_stations"], data=dfr_cleaned)

# %%
ax = sns.boxplot(x=dfr_cleaned["workplaces"], data=dfr_cleaned)

# %%
ax = sns.boxplot(x=dfr_cleaned["residential"], data=dfr_cleaned)

# %%
# take 3 variables and drop the rest

# convert df2 to matrix
X = dfr_cleaned.to_numpy()

# scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.34420497, -0.45340254, -1.31944428, ..., -0.32176765,
#          1.65181106, -1.25957553],
#        [ 0.10570159,  0.05777938, -1.09746433, ...,  0.15678179,
#          0.86526133, -0.64986986],
#        [ 0.35564968, -0.11261459, -1.56917173, ...,  0.21660047,
#          0.99635295, -0.64986986],
#        ...,
#        [-0.94408039, -1.02138246, -1.34719177, ..., -1.51814124,
#          2.04508592, -1.25957553],
#        [ 1.90532784,  0.79615327,  0.56738531, ...,  1.83170481,
#         -1.23220462,  1.7889528 ],
#        [-0.29421535, -1.47576639, -0.59800944, ..., -0.86013576,
#          2.70054403, -1.25957553]])

# %%
# list to save the clusters and cost
clusters = []
inertia_vals = []

# this whole process should take a while
for k in range(2, 15, 2):
    # train clustering with the specified K
    model = KMeans(n_clusters=k, random_state=42, n_jobs=10)
    model.fit(X)
    
    # append model to cluster list
    clusters.append(model)
    inertia_vals.append(model.inertia_)

# %%
# plot the inertia vs K values
plt.plot(range(2,15,2), inertia_vals, marker='*')
plt.xlabel('Number of K')
plt.show()

# %% [markdown]
# You can see that 4,6 and 8 can be seen as the clusters. We need to test them out

# %%
from sklearn.metrics import silhouette_score

print(clusters[1])
print("Silhouette score for k=4", silhouette_score(X, clusters[1].predict(X)))

print(clusters[2])
print("Silhouette score for k=6", silhouette_score(X, clusters[2].predict(X)))

print(clusters[3])
print("Silhouette score for k=8", silhouette_score(X, clusters[3].predict(X)))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=10, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)
# Silhouette score for k=4 0.31954829108523464
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=10, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)
# Silhouette score for k=6 0.3395679162350764
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=10, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)
# Silhouette score for k=8 0.27867615081655955

# %% [markdown]
# **As we can see, k=6 has the highest value for silhoutte score, therefore, it is 6 that we use as the number of cluster**

# %%
# visualisation of K=4 clustering solution
model = KMeans(n_clusters=6, random_state=42)
model.fit(X)

# sum of intra-cluster distances
print("Sum of intra-cluster distance:", model.inertia_)

print("Centroid locations:")
for centroid in model.cluster_centers_:
    print(centroid)

y = model.predict(X)
dfr_cleaned['Cluster ID'] = y

# how many in each
print("Cluster membership")
print(dfr_cleaned['Cluster ID'].value_counts())

# pairplot
# added alpha value to assist with overlapping points
cluster_g = sns.pairplot(dfr_cleaned, hue='Cluster ID', diag_kind='hist')
plt.show()
# Out:
# Sum of intra-cluster distance: 1443.0427386138272
# Centroid locations:
# [-1.06506976 -1.21317857 -1.09464937 -1.15635403 -0.85666801  1.14137702
#  -1.25957553]
# [ 0.73753758  0.77008206  0.0920389   0.64153863  0.70299498 -0.76586229
#   1.17924713]
# [-0.64117033 -0.14730742  0.39745066 -0.3264804  -0.94549864  0.54709842
#  -0.0401642 ]
# [ 0.79841487  0.96587108  1.90851419  0.60956226  0.38679885 -0.70315629
#   0.56954147]
# [ 1.95600225  1.41937507  0.94368694  1.67791884  1.99886934 -1.71526826
#   1.7889528 ]
# [-0.02957959 -0.24377696 -0.47929593  0.04469734  0.23294268 -0.06724608
#  -0.64986986]
# Cluster membership
# 0    207
# 5    194
# 2    185
# 1    183
# 3     84
# 4     73
# Name: Cluster ID, dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %% [markdown]
# #### Task 4: Build another clustering model using an algorithm that helps to profile the people's mobility only in some countries

# %%
df

# %%
df3=df[(df['country']=='Australia') | (df.country == 'Japan')|(df.country == 'United Kingdom')|(df.country == 'Latvia')|(df.country == 'Kenya')|(df.country == 'Romania')|(df.country == 'Slovenia')]

# %%
df3.country.unique()

# %%
country_map = {'Australia':1, 'United Kingdom': 2, 'Japan': 3, 'Kenya': 4, 'Latvia': 5, 'Romania': 6, 'Slovenia': 7}
df3['country'] = df3['country'].map(country_map)
# convert df to matrix
X = df3.to_numpy()

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
def plot_dendrogram(model, **kwargs):
    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes

# %%
X_num = [[row[0], row[2]] for row in X] # Variables of X with numeric datatype
X_cat = [[row[1]] for row in X] # variables of X with categorical datatype

# %%
model = clusters[2]

# %%
from sklearn.metrics import silhouette_score

# Calculate the Silhouette Score for the numeric and categorical variables seperately
silScoreNums = silhouette_score(X_num, model.fit_predict(X_cat[2]), metric='euclidean')
print("Silscore for numeric variables: " + str(silScoreNums))
silScoreCats = silhouette_score(X_cat, model.fit_predict(X_cat[2]), metric='hamming') # note the metric here defined to `hamming`
print("Silscore for categorical variables: " + str(silScoreCats))

# Average the silhouette scores
silScore = (silScoreNums + silScoreCats) / 2
print("The avg silhouette score for k=4: " + str(silScore))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-9d5cf9fbf791> in <module>
#       2
#       3 # Calculate the Silhouette Score for the numeric and categorical variables seperately
# ----> 4 silScoreNums = silhouette_score(X_num, model.fit_predict(X_cat[2]), metric='euclidean')
#       5 print("Silscore for numeric variables: " + str(silScoreNums))
#       6 silScoreCats = silhouette_score(X_cat, model.fit_predict(X_cat[2]), metric='hamming') # note the metric here defined to `hamming`
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit_predict(self, X, y, sample_weight)
#     996             Index of the cluster each sample belongs to.
#     997         """
# --> 998         return self.fit(X, sample_weight=sample_weight).labels_
#     999
#    1000     def fit_transform(self, X, y=None, sample_weight=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     970                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     971                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 972                 return_n_iter=True)
#     973         return self
#     974
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     310     order = "C" if copy_x else None
#     311     X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32],
# --> 312                     order=order, copy=copy_x)
#     313     # verify that the number of samples given is larger than k
#     314     if _num_samples(X) < n_clusters:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.5520294].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
Y=df2.to_numpy()
# list to save the clusters and cost
clusters1 = []
inertia_vals1 = []

# this whole process should take a while
for k in range(2, 15, 2):
    # train clustering with the specified K
    modela = KMeans(n_clusters=k, random_state=42, n_jobs=10)
    modela.fit(Y)
    
    # append model to cluster list
    clusters1.append(modela)
    inertia_vals1.append(modela.inertia_)

# %%
# plot the inertia vs K values
plt.plot(range(2,15,2), inertia_vals1, marker='*')
plt.xlabel('Number of K')
plt.show()

# %%
# Out:
# retail : 0 outliers
# grocery_and_pharmacy : 1 outliers
# parks : 9 outliers
# transit_stations : 3 outliers
# workplaces : 3 outliers
# residential : 1 outliers

# %%
# Out:
# Before transformation: %d (942, 7)
# After removing outliers: %d (926, 7)

# %%
# Out:
# Before transformation: %d (942, 7)
# After removing outliers: %d (926, 7)
